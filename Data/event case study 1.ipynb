# %%
# !pip install openpyxl
# Out:
# ...
#      ------------------------------------ 242.1/242.1 kB 380.2 kB/s eta 0:00:00
# ...

# %%
import numpy as np # linear algebra
import pandas as pd

# %%
import matplotlib.pyplot as plt
f='C:/Users/Kal Aana/Downloads/historical_emissions.xlsx'
df = pd.read_excel(f)

# %%
df.head()
# Out:
#        Country Data source                Sector      Gas      Unit   2019  \
# 0  Afghanistan        CAIT  Total excluding LUCF  All GHG     MtCO2  28.64
# 1  Afghanistan        CAIT  Total including LUCF  All GHG  MtCOâ‚‚e  28.79
# 2  Afghanistan        CAIT  Total excluding LUCF      CO2  MtCOâ‚‚e   6.08
# 3  Afghanistan        CAIT  Total excluding LUCF      CH4  MtCOâ‚‚e  16.37
# 4  Afghanistan        CAIT  Total excluding LUCF      N2O  MtCOâ‚‚e   5.01
#
#     2018   2017   2016   2015  ...   2000   1999   1998   1997   1996   1995  \
# 0  27.69  26.53  26.89  27.09  ...  13.89  15.67  14.79  13.97  13.00  11.97
# 1  27.84  26.68  27.05  26.84  ...  11.50  13.28  12.40  11.58  10.61   9.58
# 2   6.07   4.78   5.30   5.95  ...   0.76   0.81   1.04   1.10   1.18   1.24
# 3  15.91  15.61  15.83  15.96  ...   9.56  10.78   9.96   9.40   8.67   7.83
# 4   4.69   5.27   5.05   4.62  ...   3.48   4.00   3.72   3.43   3.12   2.88
#
#     1994   1993   1992   1991
# ...

# %%
df.shape
# Out:
# (1946, 34)

# %%
df.columns
# Out:
# Index([    'Country', 'Data source',      'Sector',         'Gas',
#               'Unit',          2019,          2018,          2017,
#                 2016,          2015,          2014,          2013,
#                 2012,          2011,          2010,          2009,
#                 2008,          2007,          2006,          2005,
#                 2004,          2003,          2002,          2001,
#                 2000,          1999,          1998,          1997,
#                 1996,          1995,          1994,          1993,
#                 1992,          1991],
#       dtype='object')

# %%
df=df[df['Gas'] !='F-Gas']
df.head()
# Out:
#        Country Data source                Sector      Gas      Unit   2019  \
# 0  Afghanistan        CAIT  Total excluding LUCF  All GHG     MtCO2  28.64
# 1  Afghanistan        CAIT  Total including LUCF  All GHG  MtCOâ‚‚e  28.79
# 2  Afghanistan        CAIT  Total excluding LUCF      CO2  MtCOâ‚‚e   6.08
# 3  Afghanistan        CAIT  Total excluding LUCF      CH4  MtCOâ‚‚e  16.37
# 4  Afghanistan        CAIT  Total excluding LUCF      N2O  MtCOâ‚‚e   5.01
#
#     2018   2017   2016   2015  ...   2000   1999   1998   1997   1996   1995  \
# 0  27.69  26.53  26.89  27.09  ...  13.89  15.67  14.79  13.97  13.00  11.97
# 1  27.84  26.68  27.05  26.84  ...  11.50  13.28  12.40  11.58  10.61   9.58
# 2   6.07   4.78   5.30   5.95  ...   0.76   0.81   1.04   1.10   1.18   1.24
# 3  15.91  15.61  15.83  15.96  ...   9.56  10.78   9.96   9.40   8.67   7.83
# 4   4.69   5.27   5.05   4.62  ...   3.48   4.00   3.72   3.43   3.12   2.88
#
#     1994   1993   1992   1991
# ...

# %%
df=df[df['Sector'] !='Total excluding LUCF']
df.head()
# Out:
#         Country Data source                Sector      Gas      Unit    2019  \
# 1   Afghanistan        CAIT  Total including LUCF  All GHG  MtCOâ‚‚e   28.79
# 6   Afghanistan        CAIT  Total including LUCF      CO2  MtCOâ‚‚e    6.23
# 7   Afghanistan        CAIT  Total including LUCF      CH4  MtCOâ‚‚e   16.37
# 8   Afghanistan        CAIT  Total including LUCF      N2O  MtCOâ‚‚e    5.01
# 11       Angola        CAIT  Total including LUCF  All GHG  MtCOâ‚‚e  128.29
#
#       2018    2017    2016    2015  ...   2000   1999   1998   1997   1996  \
# 1    27.84   26.68   27.05   26.84  ...  11.50  13.28  12.40  11.58  10.61
# 6     6.22    4.94    5.46    5.70  ...  -1.63  -1.58  -1.35  -1.29  -1.21
# 7    15.91   15.61   15.83   15.96  ...   9.56  10.78   9.96   9.40   8.67
# 8     4.69    5.27    5.05    4.62  ...   3.48   4.00   3.72   3.43   3.12
# 11  120.10  131.15  133.52  135.83  ...  81.34  87.51  89.91  80.52  81.52
#
#      1995   1994   1993   1992   1991
# ...

# %%
df.shape
# Out:
# (780, 34)

# %%
df=df[df['Country'] !='World']
df.head()
# Out:
#         Country Data source                Sector      Gas      Unit    2019  \
# 1   Afghanistan        CAIT  Total including LUCF  All GHG  MtCOâ‚‚e   28.79
# 6   Afghanistan        CAIT  Total including LUCF      CO2  MtCOâ‚‚e    6.23
# 7   Afghanistan        CAIT  Total including LUCF      CH4  MtCOâ‚‚e   16.37
# 8   Afghanistan        CAIT  Total including LUCF      N2O  MtCOâ‚‚e    5.01
# 11       Angola        CAIT  Total including LUCF  All GHG  MtCOâ‚‚e  128.29
#
#       2018    2017    2016    2015  ...   2000   1999   1998   1997   1996  \
# 1    27.84   26.68   27.05   26.84  ...  11.50  13.28  12.40  11.58  10.61
# 6     6.22    4.94    5.46    5.70  ...  -1.63  -1.58  -1.35  -1.29  -1.21
# 7    15.91   15.61   15.83   15.96  ...   9.56  10.78   9.96   9.40   8.67
# 8     4.69    5.27    5.05    4.62  ...   3.48   4.00   3.72   3.43   3.12
# 11  120.10  131.15  133.52  135.83  ...  81.34  87.51  89.91  80.52  81.52
#
#      1995   1994   1993   1992   1991
# ...

# %%
df.shape
# Out:
# (776, 34)

# %%
df.drop(['Data source','Sector','Unit'],axis=1,inplace=True)

# %%
df.head()
# Out:
#         Country      Gas    2019    2018    2017    2016    2015    2014  \
# 1   Afghanistan  All GHG   28.79   27.84   26.68   27.05   26.84   26.52
# 6   Afghanistan      CO2    6.23    6.22    4.94    5.46    5.70    4.63
# 7   Afghanistan      CH4   16.37   15.91   15.61   15.83   15.96   16.30
# 8   Afghanistan      N2O    5.01    4.69    5.27    5.05    4.62    5.09
# 11       Angola  All GHG  128.29  120.10  131.15  133.52  135.83  129.91
#
#       2013    2012  ...   2000   1999   1998   1997   1996   1995   1994  \
# 1    26.77   28.55  ...  11.50  13.28  12.40  11.58  10.61   9.58   9.15
# 6     5.74    7.83  ...  -1.63  -1.58  -1.35  -1.29  -1.21  -1.15  -1.10
# 7    15.82   15.63  ...   9.56  10.78   9.96   9.40   8.67   7.83   7.47
# 8     4.77    4.72  ...   3.48   4.00   3.72   3.43   3.12   2.88   2.76
# 11  128.10  125.68  ...  81.34  87.51  89.91  80.52  81.52  76.32  73.16
#
#      1993   1992   1991
# 1    9.11   9.03   9.81
# 6   -1.05  -1.00  -0.16
# ...

# %%
df['Country'].unique()
# Out:
# array(['Afghanistan', 'Angola', 'Albania', 'Andorra',
#        'United Arab Emirates', 'Argentina', 'Armenia',
#        'Antigua and Barbuda', 'Australia', 'Austria', 'Azerbaijan',
#        'Burundi', 'Belgium', 'Benin', 'Burkina Faso', 'Bangladesh',
#        'Bulgaria', 'Bahrain', 'Bahamas', 'Bosnia and Herzegovina',
#        'Belarus', 'Belize', 'Bolivia', 'Brazil', 'Barbados', 'Brunei',
#        'Bhutan', 'Botswana', 'Central African Republic', 'Canada',
#        'Switzerland', 'Chile', 'China', "CÃ´te d'Ivoire", 'Cameroon',
#        'Democratic Republic of the Congo', 'Republic of Congo',
#        'Cook Islands', 'Colombia', 'Comoros', 'Cape Verde', 'Costa Rica',
#        'Cuba', 'Cyprus', 'Czech Republic', 'Germany', 'Djibouti',
#        'Dominica', 'Denmark', 'Dominican Republic', 'Algeria', 'Ecuador',
#        'Egypt', 'Eritrea', 'Spain', 'Estonia', 'Ethiopia',
#        'European Union (27)', 'Finland', 'Fiji', 'France', 'Micronesia',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 776 entries, 1 to 1944
# Data columns (total 31 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  776 non-null    object
#  1   Gas      776 non-null    object
#  2   2019     776 non-null    float64
#  3   2018     776 non-null    float64
#  4   2017     776 non-null    float64
#  5   2016     776 non-null    float64
#  6   2015     776 non-null    float64
#  7   2014     776 non-null    float64
#  8   2013     776 non-null    float64
#  9   2012     776 non-null    float64
#  10  2011     776 non-null    float64
#  11  2010     776 non-null    float64
#  12  2009     776 non-null    float64
#  13  2008     776 non-null    float64
#  14  2007     776 non-null    float64
#  15  2006     776 non-null    float64
#  16  2005     776 non-null    float64
#  17  2004     776 non-null    float64
#  18  2003     776 non-null    float64
#  19  2002     776 non-null    float64
# ...

# %%
# save the dataframe to a new file
df.to_csv('C:/Users/Kal Aana/Downloads/historical_emissions_final.csv', index=False)

# %%
df=pd.read_csv('C:/Users/Kal Aana/Downloads/historical_emissions_final.csv')
df.head()
# Out:
#        Country      Gas    2019    2018    2017    2016    2015    2014  \
# 0  Afghanistan  All GHG   28.79   27.84   26.68   27.05   26.84   26.52
# 1  Afghanistan      CO2    6.23    6.22    4.94    5.46    5.70    4.63
# 2  Afghanistan      CH4   16.37   15.91   15.61   15.83   15.96   16.30
# 3  Afghanistan      N2O    5.01    4.69    5.27    5.05    4.62    5.09
# 4       Angola  All GHG  128.29  120.10  131.15  133.52  135.83  129.91
#
#      2013    2012  ...   2000   1999   1998   1997   1996   1995   1994  \
# 0   26.77   28.55  ...  11.50  13.28  12.40  11.58  10.61   9.58   9.15
# 1    5.74    7.83  ...  -1.63  -1.58  -1.35  -1.29  -1.21  -1.15  -1.10
# 2   15.82   15.63  ...   9.56  10.78   9.96   9.40   8.67   7.83   7.47
# 3    4.77    4.72  ...   3.48   4.00   3.72   3.43   3.12   2.88   2.76
# 4  128.10  125.68  ...  81.34  87.51  89.91  80.52  81.52  76.32  73.16
#
#     1993   1992   1991
# 0   9.11   9.03   9.81
# 1  -1.05  -1.00  -0.16
# 2   7.21   7.13   7.02
# ...

# %%
india = df[df['Country']=='India']
india
# Out:
#     Country      Gas     2019     2018     2017     2016     2015     2014  \
# 316   India  All GHG  3363.60  3360.56  3215.07  3076.48  3003.07  2984.52
# 317   India      CO2  2422.03  2417.66  2286.13  2160.98  2093.18  2082.27
# 318   India      CH4   658.09   657.15   650.82   645.12   640.43   637.04
# 319   India      N2O   261.74   265.59   259.55   253.40   254.05   250.58
#
#         2013     2012  ...     2000     1999     1998     1997     1996  \
# 316  2804.34  2740.40  ...  1477.87  1440.38  1362.33  1331.88  1272.74
# 317  1907.60  1844.61  ...   716.76   680.23   615.17   598.17   552.95
# 318   634.57   632.59  ...   573.00   569.23   560.55   551.86   543.92
# 319   248.33   250.14  ...   180.54   184.19   180.72   176.81   171.67
#
#         1995     1994     1993     1992     1991
# 316  1223.65  1158.48  1114.22  1081.28  1056.25
# 317   516.73   464.74   430.19   405.13   386.06
# 318   535.25   525.93   522.27   518.28   516.81
# ...

# %%
india.columns
# Out:
# Index(['Country', 'Gas', '2019', '2018', '2017', '2016', '2015', '2014',
#        '2013', '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005',
#        '2004', '2003', '2002', '2001', '2000', '1999', '1998', '1997', '1996',
#        '1995', '1994', '1993', '1992', '1991'],
#       dtype='object')

# %%
2422.03-2417.66
# Out:
# 4.370000000000346

# %%
# Get change in CO2 emissions from 2018 to 2019
india['2019'] - india['2018']
# Out:
# 316    3.04
# 317    4.37
# 318    0.94
# 319   -3.85
# dtype: float64

# %%
india.iloc[:,2:7]
# Out:
#         2019     2018     2017     2016     2015
# 316  3363.60  3360.56  3215.07  3076.48  3003.07
# 317  2422.03  2417.66  2286.13  2160.98  2093.18
# 318   658.09   657.15   650.82   645.12   640.43
# 319   261.74   265.59   259.55   253.40   254.05

# %%
# Get Average of 5 columns
india.iloc[:,2:7].mean(axis=1)
# Out:
# 316    3203.756
# 317    2275.996
# 318     650.322
# 319     258.866
# dtype: float64

# %%
a= india['2019'] - india['1991']
a
# Out:
# 316    2307.35
# 317    2035.97
# 318     141.28
# 319     110.34
# dtype: float64

# %%
# Percentage change in CH4 emissions from 1991 to 2019
a= india['2019'] - india['1991']
b=a/india['1991']*100
b
# Out:
# 316    218.447337
# 317    527.371393
# 318     27.336932
# 319     72.879789
# dtype: float64

# %%
1.2733*516.81
# Out:
# 658.054173

# %%
# Get biggest All GHG emissions Country for 2019
D=df[df['Gas']=='All GHG']
D=D.sort_values(by='2019',ascending=False)
D.head()
# Out:
#                  Country      Gas      2019      2018      2017      2016  \
# 128                China  All GHG  12055.41  11821.66  11385.48  11151.31
# 732        United States  All GHG   5771.00   5892.37   5689.61   5743.85
# 316                India  All GHG   3363.60   3360.56   3215.07   3076.48
# 228  European Union (27)  All GHG   3149.57   3295.53   3379.38   3364.77
# 312            Indonesia  All GHG   1959.71   1692.36   1447.22   1434.46
#
#          2015      2014      2013      2012  ...     2000     1999     1998  \
# 128  11108.86  11228.48  11168.26  10675.66  ...  4221.08  4028.58  4095.97
# 732   5665.21   5779.54   5734.28   5593.25  ...  6372.54  6210.12  6208.83
# 316   3003.07   2984.52   2804.34   2740.40  ...  1477.87  1440.38  1362.33
# 228   3019.49   2962.68   3109.55   3188.85  ...  3877.33  3874.40  3949.25
# 312   2067.75   2015.50   1638.39   1702.30  ...  1190.41  1258.63  1366.90
#
# ...

# %%
# Get biggest All GHG emissions Country for 2000
D=df[df['Gas']=='All GHG']
D=D.sort_values(by='2000',ascending=False)
D.head(10)
# Out:
#                  Country      Gas      2019      2018      2017      2016  \
# 732        United States  All GHG   5771.00   5892.37   5689.61   5743.85
# 128                China  All GHG  12055.41  11821.66  11385.48  11151.31
# 228  European Union (27)  All GHG   3149.57   3295.53   3379.38   3364.77
# 592               Russia  All GHG   1924.82   1868.15   1769.69   1733.91
# 92                Brazil  All GHG   1451.63   1434.51   1475.82   1455.86
# 316                India  All GHG   3363.60   3360.56   3215.07   3076.48
# 352                Japan  All GHG   1134.45   1172.32   1214.59   1229.82
# 312            Indonesia  All GHG   1959.71   1692.36   1447.22   1434.46
# 180              Germany  All GHG    720.23    771.48    800.21    817.47
# 116               Canada  All GHG    774.29    776.50    757.38    740.67
#
#          2015      2014      2013      2012  ...     2000     1999     1998  \
# 732   5665.21   5779.54   5734.28   5593.25  ...  6372.54  6210.12  6208.83
# ...

# %%
# Get biggest All GHG emissions Country for 1991
D=df[df['Gas']=='All GHG']
D=D.sort_values(by='1991',ascending=False)
D.head(10)
# Out:
#                  Country      Gas      2019      2018      2017      2016  \
# 732        United States  All GHG   5771.00   5892.37   5689.61   5743.85
# 228  European Union (27)  All GHG   3149.57   3295.53   3379.38   3364.77
# 128                China  All GHG  12055.41  11821.66  11385.48  11151.31
# 592               Russia  All GHG   1924.82   1868.15   1769.69   1733.91
# 92                Brazil  All GHG   1451.63   1434.51   1475.82   1455.86
# 312            Indonesia  All GHG   1959.71   1692.36   1447.22   1434.46
# 352                Japan  All GHG   1134.45   1172.32   1214.59   1229.82
# 316                India  All GHG   3363.60   3360.56   3215.07   3076.48
# 180              Germany  All GHG    720.23    771.48    800.21    817.47
# 252       United Kingdom  All GHG    429.13    442.48    450.65    465.58
#
#          2015      2014      2013      2012  ...     2000     1999     1998  \
# 732   5665.21   5779.54   5734.28   5593.25  ...  6372.54  6210.12  6208.83
# ...

# %%
# Get biggest All GHG emissions Country for 1991
D=df[df['Gas']=='All GHG']
D=D.sort_values(by='2018',ascending=False)
D.head(10)
# Out:
#                  Country      Gas      2019      2018      2017      2016  \
# 128                China  All GHG  12055.41  11821.66  11385.48  11151.31
# 732        United States  All GHG   5771.00   5892.37   5689.61   5743.85
# 316                India  All GHG   3363.60   3360.56   3215.07   3076.48
# 228  European Union (27)  All GHG   3149.57   3295.53   3379.38   3364.77
# 592               Russia  All GHG   1924.82   1868.15   1769.69   1733.91
# 312            Indonesia  All GHG   1959.71   1692.36   1447.22   1434.46
# 92                Brazil  All GHG   1451.63   1434.51   1475.82   1455.86
# 352                Japan  All GHG   1134.45   1172.32   1214.59   1229.82
# 324                 Iran  All GHG    893.78    925.58    912.77    881.05
# 116               Canada  All GHG    774.29    776.50    757.38    740.67
#
#          2015      2014      2013      2012  ...     2000     1999     1998  \
# 128  11108.86  11228.48  11168.26  10675.66  ...  4221.08  4028.58  4095.97
# ...

# %%
# Average C02 Emission for United States
D=df[df['Country']=='United States']
D=D[D['Gas']=='CO2']
D
# Out:
#            Country  Gas     2019     2018     2017     2016     2015     2014  \
# 733  United States  CO2  4585.99  4743.58  4587.55  4662.71  4571.45  4687.99
#
#         2013     2012  ...     2000     1999    1998     1997     1996  \
# 733  4672.94  4537.01  ...  5357.28  5190.39  5171.9  5124.65  4854.84
#
#         1995     1994     1993     1992     1991
# 733  4698.45  4648.09  4576.63  4461.04  4388.91
#
# [1 rows x 31 columns]

# %%
# Plotting the data

# %%
D.iloc[:,2:].mean(axis=1)
# Out:
# 733    4905.091724
# dtype: float64

# %%
# Get biggest n20 emissions Country for 2000
D=df[df['Gas']=='N2O']
D=D.sort_values(by='2019',ascending=False)
D.head(10)
# Out:
#                  Country  Gas    2019    2018    2017    2016    2015    2014  \
# 131                China  N2O  552.28  545.19  548.88  552.67  549.62  534.42
# 735        United States  N2O  265.74  268.55  267.10  267.18  261.11  262.03
# 319                India  N2O  261.74  265.59  259.55  253.40  254.05  250.58
# 231  European Union (27)  N2O  214.84  213.23  218.76  217.62  219.55  217.85
# 95                Brazil  N2O  187.29  180.39  190.00  179.65  176.37  176.57
# 315            Indonesia  N2O   99.40   98.37   94.83   88.85   88.89   88.02
# 35             Australia  N2O   71.46   77.69   80.04   58.23   72.50   76.46
# 547             Pakistan  N2O   66.67   65.74   64.63   60.97   58.25   57.07
# 595               Russia  N2O   65.12   64.67   62.43   63.32   58.68   61.02
# 139             Cameroon  N2O   62.63   62.50   62.59   62.63   62.38   62.28
#
#        2013    2012  ...    2000    1999    1998    1997    1996    1995  \
# ...

# %%
# get total CH4 Emission for China between 2010 to 2019
D=df[df['Country']=='China']
D=D[D['Gas']=='CH4']
D
# Out:
#     Country  Gas     2019     2018     2017     2016     2015     2014  \
# 130   China  CH4  1176.34  1159.28  1131.63  1120.35  1159.87  1161.42
#
#         2013     2012  ...    2000    1999    1998    1997    1996    1995  \
# 130  1147.21  1122.85  ...  810.19  810.42  815.85  813.78  858.79  850.31
#
#        1994    1993    1992    1991
# 130  812.96  790.54  781.19  775.53
#
# [1 rows x 31 columns]

# %%
D.iloc[:,2:12].sum(axis=1)
# Out:
# 130    11373.56
# dtype: float64
